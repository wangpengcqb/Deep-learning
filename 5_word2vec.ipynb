# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(len(batch))])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.893417
# Nearest to more: sinkholes, juridical, mediation, crested, represented, brant, octavia, bmj,
# Nearest to that: colourless, broadbent, lamellar, cumings, geschichte, consigned, chk, mollusks,
# Nearest to the: webelements, koo, identification, fault, roddenberry, stair, submission, geosynchronous,
# Nearest to but: webcomic, mujahedin, pga, platonic, odor, rai, filename, equivocal,
# Nearest to has: doppler, improvising, psychosis, reproductions, filipino, circumcised, ldl, abidjan,
# Nearest to after: mordant, lincoln, tasso, ibm, schuler, fished, solar, chartered,
# Nearest to was: umlaut, salamanders, elliptic, wedge, hanssen, roussimoff, misspelling, futhark,
# Nearest to other: special, exorbitant, colitis, exegetical, foil, martens, interdependence, loss,
# Nearest to i: noblemen, indignation, rica, verb, disproportionately, shelby, rebelling, fuss,
# Nearest to at: somewhere, transcendent, speakers, subtractive, personalities, posters, migrate, aai,
# Nearest to however: haggis, hairdresser, scrambled, accumulate, convent, britanniae, philips, vsl,
# Nearest to years: associating, tydings, chaim, suk, scholasticus, necessities, hammering, accomplish,
# Nearest to history: manifested, eo, lobbying, prentice, chooses, bhishma, volvo, djamena,
# Nearest to new: totality, montezuma, actionscript, receipt, fatou, fretless, oral, over,
# Nearest to as: fruit, redirection, fermi, corners, volante, gry, sources, lancer,
# Nearest to may: pissarro, hooke, baryon, dell, unrestricted, allegro, sacrament, mahjong,
# Average loss at step 2000: 4.362691
# Average loss at step 4000: 3.859754
# Average loss at step 6000: 3.790528
# Average loss at step 8000: 3.686940
# Average loss at step 10000: 3.612133
# Nearest to more: clarification, less, sinkholes, icbms, powerless, embellished, medici, unfashionable,
# Nearest to that: which, it, raul, usually, this, korah, cannibals, mitsubishi,
# Nearest to the: a, this, its, his, an, their, warmly, norodom,
# Nearest to but: and, though, which, backbench, sexist, gdr, restraining, will,
# Nearest to has: have, had, was, is, publicized, hamlin, xbox, standardization,
# Nearest to after: schuler, deported, solar, larousse, chartered, lincoln, booked, toed,
# Nearest to was: is, has, had, were, umlaut, pikemen, walser, by,
# Nearest to other: exorbitant, special, ich, drinking, others, these, languages, colitis,
# Nearest to i: noblemen, rebelling, t, sharps, ibid, pmrc, scrip, replied,
# Nearest to at: in, from, by, escorting, somewhere, posters, of, fca,
# Nearest to however: convent, hairdresser, haggis, sees, resolutely, argentinean, mithraea, widgets,
# Nearest to years: tydings, associating, rationalistic, defendants, chaim, cri, usenet, days,
# Nearest to history: lobbying, localities, chooses, canossa, necks, crust, mur, code,
# Nearest to new: totality, fatou, receipt, dorians, over, actionscript, haryana, soviets,
# Nearest to as: attain, grossing, humidity, observed, sukhum, be, became, substituted,
# Nearest to may: will, can, bah, baryon, advert, equip, misunderstandings, compensates,
# Average loss at step 12000: 3.607353
# Average loss at step 14000: 3.568075
# Average loss at step 16000: 3.407012
# Average loss at step 18000: 3.460396
# Average loss at step 20000: 3.542511
# Nearest to more: less, most, clarification, powerless, bruton, unfashionable, profusion, maibock,
# Nearest to that: which, mitsubishi, but, this, when, cannibals, raul, printer,
# Nearest to the: their, its, a, his, an, diplomacy, this, heritage,
# Nearest to but: however, though, which, although, will, and, if, that,
# Nearest to has: had, was, have, is, does, universal, xbox, although,
# Nearest to after: before, during, deported, corvette, solar, sergey, when, was,
# Nearest to was: is, has, were, had, be, became, are, by,
# Nearest to other: many, these, some, exorbitant, languages, are, pints, others,
# Nearest to i: ii, t, scrip, iii, norway, moveable, petrie, emulate,
# Nearest to at: in, from, and, on, orbiting, posters, for, platonism,
# Nearest to however: but, argentinean, convent, though, they, sees, enzymatic, resolutely,
# Nearest to years: days, tydings, lemnos, cri, suk, associating, rationalistic, hundred,
# Nearest to history: lobbying, code, canossa, localities, mur, late, crust, frontage,
# Nearest to new: receipt, dorians, fatou, transfusions, displaced, haryana, pygmies, dpp,
# Nearest to as: sukhum, ystok, when, elca, became, valentine, pronounced, principate,
# Nearest to may: can, will, would, could, should, must, might, to,
# Average loss at step 22000: 3.504609
# Average loss at step 24000: 3.491139
# Average loss at step 26000: 3.478127
# Average loss at step 28000: 3.479796
# Average loss at step 30000: 3.498255
# Nearest to more: less, most, clarification, bruton, very, profusion, lichens, powerless,
# Nearest to that: which, this, raul, what, however, but, cannibals, bangkok,
# Nearest to the: their, its, his, some, a, webelements, many, coveted,
# Nearest to but: however, although, and, though, which, is, if, did,
# Nearest to has: had, have, is, was, does, ambedkar, olga, beltane,
# Nearest to after: before, during, when, from, sergey, since, was, corvette,
# Nearest to was: is, had, were, has, became, been, be, being,
# Nearest to other: some, these, different, many, various, twists, pints, interest,
# Nearest to i: ii, iii, t, we, associations, they, savior, she,
# Nearest to at: in, schleswig, during, expatriate, stratigraphy, around, scoreless, sergey,
# Nearest to however: but, though, although, and, that, kokomo, resolutely, sees,
# Nearest to years: days, months, lemnos, cri, times, consciousness, tydings, suk,
# Nearest to history: lobbying, code, canossa, development, localities, althusser, late, croat,
# Nearest to new: transfusions, dorians, kiwifruit, second, receipt, tente, gubernatorial, codification,
# Nearest to as: monastic, phallus, with, by, and, became, affricates, is,
# Nearest to may: can, will, would, could, should, must, might, bah,
# Average loss at step 32000: 3.500508
# Average loss at step 34000: 3.490202
# Average loss at step 36000: 3.455551
# Average loss at step 38000: 3.301249
# Average loss at step 40000: 3.426563
# Nearest to more: less, most, very, clarification, bruton, greater, quite, outfit,
# Nearest to that: which, this, what, however, because, where, but, maitreya,
# Nearest to the: this, a, their, his, its, invariants, some, each,
# Nearest to but: however, although, though, are, and, when, while, which,
# Nearest to has: had, have, is, was, battery, witherspoon, ejection, contains,
# Nearest to after: before, during, when, while, was, distancing, corvette, since,
# Nearest to was: is, had, were, became, has, be, been, after,
# Nearest to other: different, various, many, ascertaining, some, plummer, papyrus, human,
# Nearest to i: ii, we, he, t, they, iii, insemination, she,
# Nearest to at: in, during, stratigraphy, on, ghilzai, cim, keillor, schleswig,
# Nearest to however: but, though, although, they, that, sees, while, kokomo,
# Nearest to years: days, months, lemnos, times, decades, cri, year, hundred,
# Nearest to history: lobbying, tetrameter, rdenas, wends, janitor, code, kuiper, tribe,
# Nearest to new: gubernatorial, second, dorians, meander, university, transfusions, speculator, graphing,
# Nearest to as: elca, principate, tonal, when, wrapper, sukhum, roden, by,
# Nearest to may: can, will, would, could, must, should, might, to,
# Average loss at step 42000: 3.435905
# Average loss at step 44000: 3.453128
# Average loss at step 46000: 3.448520
# Average loss at step 48000: 3.361266
# Average loss at step 50000: 3.376041
# Nearest to more: less, most, bruton, very, quite, clarification, lichens, greater,
# Nearest to that: which, however, what, but, this, cannibals, pistons, korah,
# Nearest to the: its, their, any, this, a, some, eraser, our,
# Nearest to but: however, although, and, though, when, while, lucille, he,
# Nearest to has: had, have, was, is, does, witherspoon, gallons, contains,
# Nearest to after: before, when, during, while, corvette, since, although, sergey,
# Nearest to was: is, were, has, became, been, had, be, by,
# Nearest to other: various, different, some, many, others, these, plummer, blogger,
# Nearest to i: ii, we, you, insemination, t, iii, joliet, he,
# Nearest to at: during, in, on, around, against, from, schleswig, stratigraphy,
# Nearest to however: but, although, though, that, when, while, weinberger, where,
# Nearest to years: days, months, times, decades, year, lemnos, canopus, hundred,
# Nearest to history: lobbying, janitor, tribe, rdenas, pi, study, wends, fundamental,
# Nearest to new: brief, transfusions, fourth, gubernatorial, few, gabriel, essendon, dorians,
# Nearest to as: became, parton, discourage, becoming, principate, peptide, sukhum, erodes,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Average loss at step 52000: 3.436683
# Average loss at step 54000: 3.425563
# Average loss at step 56000: 3.439370
# Average loss at step 58000: 3.395696
# Average loss at step 60000: 3.395073
# Nearest to more: less, most, very, greater, bruton, rather, longer, smaller,
# Nearest to that: which, what, this, however, where, it, raul, who,
# Nearest to the: their, its, a, each, this, any, zeit, warmly,
# Nearest to but: however, although, and, when, though, which, lucille, hypomania,
# Nearest to has: had, have, was, is, contains, witherspoon, graded, avoided,
# Nearest to after: before, during, when, while, despite, without, although, since,
# Nearest to was: is, had, became, were, has, be, been, when,
# Nearest to other: various, different, spliced, many, plummer, including, plenary, blogger,
# Nearest to i: we, ii, you, t, iii, insemination, associations, he,
# Nearest to at: in, during, schleswig, near, keillor, kiosk, stratigraphy, lighthearted,
# Nearest to however: but, although, though, that, which, when, while, since,
# Nearest to years: days, months, decades, times, year, weeks, canopus, kadyrov,
# Nearest to history: list, tetrameter, earliest, tribe, politics, fundamental, kuiper, charlestown,
# Nearest to new: second, fourth, gubernatorial, brief, graphing, convalescence, transfusions, dorians,
# Nearest to as: when, parton, sukhum, monastic, principate, reciprocity, chiefdoms, became,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Average loss at step 62000: 3.236830
# Average loss at step 64000: 3.253225
# Average loss at step 66000: 3.404030
# Average loss at step 68000: 3.396063
# Average loss at step 70000: 3.364594
# Nearest to more: less, most, very, rather, longer, smaller, greater, bruton,
# Nearest to that: which, however, what, this, bangkok, but, where, pistons,
# Nearest to the: their, a, this, its, each, any, another, these,
# Nearest to but: however, although, though, and, which, that, when, obviously,
# Nearest to has: had, have, is, was, contains, since, although, graded,
# Nearest to after: before, during, when, while, despite, until, hydro, sergey,
# Nearest to was: is, had, has, were, been, became, be, being,
# Nearest to other: various, different, many, spliced, mods, including, obiang, others,
# Nearest to i: ii, we, miso, you, insemination, g, sure, politican,
# Nearest to at: during, around, in, near, schleswig, cim, on, allows,
# Nearest to however: but, though, although, that, while, when, where, which,
# Nearest to years: days, months, decades, year, times, weeks, kadyrov, percent,
# Nearest to history: list, charlestown, tetrameter, rdenas, unaffected, ago, earliest, althusser,
# Nearest to new: particular, dorians, brief, heimdall, codification, graphing, gubernatorial, gabriel,
# Nearest to as: when, by, parton, principate, like, microchips, boundless, nautilus,
# Nearest to may: can, will, could, would, must, should, might, cannot,
# Average loss at step 72000: 3.371181
# Average loss at step 74000: 3.348522
# Average loss at step 76000: 3.314096
# Average loss at step 78000: 3.352036
# Average loss at step 80000: 3.376945
# Nearest to more: less, very, most, quite, rather, bruton, powerless, highly,
# Nearest to that: which, however, what, where, pistons, raul, syme, but,
# Nearest to the: its, their, this, his, your, a, eraser, jaya,
# Nearest to but: however, although, though, and, while, than, lucille, which,
# Nearest to has: had, have, is, was, since, auxiliary, although, contains,
# Nearest to after: before, during, when, while, despite, from, following, until,
# Nearest to was: is, were, has, had, became, been, when, during,
# Nearest to other: various, others, many, different, some, western, mods, older,
# Nearest to i: ii, we, you, t, g, iii, baudot, insemination,
# Nearest to at: in, schleswig, on, around, during, stratigraphy, moniker, lighthearted,
# Nearest to however: although, but, though, that, where, while, when, including,
# Nearest to years: days, months, decades, year, times, weeks, hours, canopus,
# Nearest to history: list, charlestown, earliest, rdenas, arcseconds, lobbying, zelda, usage,
# Nearest to new: dorians, heimdall, quintessentially, tente, gabriel, graphing, codification, tm,
# Nearest to as: principate, beside, elca, acacia, parton, became, transoxiana, dualist,
# Nearest to may: can, could, will, would, must, should, might, cannot,
# Average loss at step 82000: 3.409158
# Average loss at step 84000: 3.410304
# Average loss at step 86000: 3.393723
# Average loss at step 88000: 3.352744
# Average loss at step 90000: 3.366206
# Nearest to more: less, most, very, rather, quite, increasingly, highly, powerless,
# Nearest to that: which, however, what, bangkok, but, chk, cannibals, pedestal,
# Nearest to the: its, this, his, their, a, whose, ckel, any,
# Nearest to but: however, although, and, while, though, they, he, swings,
# Nearest to has: had, have, is, was, since, having, does, contains,
# Nearest to after: before, during, when, despite, while, until, without, hydro,
# Nearest to was: is, had, were, became, has, be, been, agarose,
# Nearest to other: various, individual, including, different, others, mods, plenary, blogger,
# Nearest to i: ii, we, g, you, t, iii, baudot, miso,
# Nearest to at: during, under, despite, around, university, in, stratigraphy, schleswig,
# Nearest to however: but, although, though, that, while, where, which, when,
# Nearest to years: days, months, decades, year, hours, times, weeks, centuries,
# Nearest to history: list, charlestown, earliest, lobbying, rdenas, usage, tetrameter, arcseconds,
# Nearest to new: dorians, codification, quintessentially, modern, gabriel, different, particular, tente,
# Nearest to as: elca, principate, affricates, meuse, peptide, manifest, grossing, gabrielle,
# Nearest to may: can, could, would, must, might, should, will, cannot,
# Average loss at step 92000: 3.400736
# Average loss at step 94000: 3.254490
# Average loss at step 96000: 3.356643
# Average loss at step 98000: 3.242035
# Average loss at step 100000: 3.355435
# Nearest to more: less, very, most, rather, quite, highly, larger, greater,
# Nearest to that: which, however, what, pedestal, who, raul, orbis, chk,
# Nearest to the: their, his, a, its, some, your, this, whose,
# Nearest to but: however, although, though, and, while, when, which, yet,
# Nearest to has: had, have, is, was, having, since, provides, contains,
# Nearest to after: before, during, when, despite, without, while, until, following,
# Nearest to was: is, has, became, were, had, when, being, been,
# Nearest to other: various, mods, individual, others, older, fewer, blogger, spliced,
# Nearest to i: we, ii, you, t, iii, they, happiest, baudot,
# Nearest to at: during, in, from, near, schleswig, on, around, median,
# Nearest to however: but, although, though, that, while, where, which, and,
# Nearest to years: days, months, decades, year, weeks, times, hours, centuries,
# Nearest to history: list, charlestown, rdenas, delgado, crossed, earliest, origins, arcseconds,
# Nearest to new: modern, dorians, previous, quintessentially, codification, gabriel, few, particular,
# Nearest to as: principate, wrapper, sukhum, when, zuid, affricates, severed, peptide,
# Nearest to may: can, could, must, would, might, should, will, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0
 
def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels
 
print('data:', [reverse_dictionary[di] for di in data[:16]])
 
for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.
 
graph = tf.Graph()
 
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
 
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
 
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
 
    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
 
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
 
num_steps = 100001
 
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
 
num_points = 400
 
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])
 
 
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()
 
 
words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
# Out:
# Initialized
# Average loss at step 0: 8.139589
# Nearest to were: books, illegally, albatrosses, calculating, germinal, isomers, edges, ve,
# Nearest to there: labeling, bjarne, bishkek, indepth, serine, ribs, nashe, intersected,
# Nearest to or: sporadic, pubs, telethon, cummins, moldova, reviews, tradeoffs, subjugating,
# Nearest to many: speckled, nieces, invasion, fasttrack, fugal, miscible, messerschmitt, stingray,
# Nearest to are: fingerprints, impetus, percent, withdraws, realpolitik, uncivilized, licensees, bertolucci,
# Nearest to was: dom, notoriety, borrowers, chap, armenia, peacetime, documenting, owed,
# Nearest to four: hussars, spike, censuses, tiled, srivijaya, netted, talib, colonist,
# Nearest to six: tonle, granted, manuals, stronghold, htp, syphilis, biggest, dijon,
# Nearest to war: detractors, xb, thanked, addressing, inductive, hksar, cheating, surrendered,
# Nearest to other: consecutive, deregulation, paints, boito, archived, sufferers, bought, spoiling,
# Nearest to however: pilgrimages, neoconservatism, japh, algirdas, surveyed, oakley, optimates, things,
# Nearest to all: mineralogical, canadiens, criminalization, dogbert, maglev, proof, waylon, morons,
# Nearest to the: leni, warez, adaptable, censoring, owls, inexperience, daedalus, explanations,
# Nearest to i: comma, luncheon, plating, optionally, rediscovered, ignite, swapped, weaponry,
# Nearest to states: californian, convert, gap, fortune, division, sasson, detriment, clitoris,
# Nearest to during: cronje, sharm, mather, pencils, pg, renegades, gv, obsessed,
# Average loss at step 2000: 4.584009
# Average loss at step 4000: 3.932442
# Average loss at step 6000: 3.716313
# Average loss at step 8000: 3.522095
# Average loss at step 10000: 3.477973
# Nearest to were: are, was, is, had, excessive, alai, antiochus, cadets,
# Nearest to there: it, they, indepth, benefiting, liga, these, used, considered,
# Nearest to or: and, than, comers, yttrium, risc, petitioner, pfc, transmitters,
# Nearest to many: some, several, all, other, various, most, imi, neglect,
# Nearest to are: were, is, was, include, have, workhorse, persist, other,
# Nearest to was: is, were, has, became, are, had, being, ehr,
# Nearest to four: three, five, eight, six, nine, seven, zero, two,
# Nearest to six: eight, nine, four, five, three, seven, zero, unsuited,
# Nearest to war: xb, incarcerated, wars, largest, nassau, bryozoa, cooperates, relinquish,
# Nearest to other: different, many, some, more, various, these, keto, are,
# Nearest to however: but, glories, neoconservatism, lacaille, although, maka, gees, finegold,
# Nearest to all: many, equated, some, several, looting, these, any, various,
# Nearest to the: its, a, pravda, any, his, this, clades, evers,
# Nearest to i: kyrgyz, castration, ii, leftism, predict, recycled, rafe, they,
# Nearest to states: kingdom, vassar, gap, division, deformed, chirality, chanel, massoud,
# Nearest to during: after, in, garner, before, over, entre, salisbury, when,
# Average loss at step 12000: 3.490233
# Average loss at step 14000: 3.431777
# Average loss at step 16000: 3.435486
# Average loss at step 18000: 3.410740
# Average loss at step 20000: 3.209481
# Nearest to were: are, was, being, is, persist, have, include, became,
# Nearest to there: they, liga, it, unconstitutional, these, fortunately, which, given,
# Nearest to or: and, than, clement, overran, intransitive, dih, cry, exploded,
# Nearest to many: some, several, various, all, these, most, numerous, each,
# Nearest to are: were, is, being, have, include, was, longitudes, butter,
# Nearest to was: is, were, became, had, being, are, has, dummy,
# Nearest to four: seven, five, six, eight, three, two, one, nine,
# Nearest to six: seven, five, eight, four, three, zero, nine, two,
# Nearest to war: wars, exceeded, incarcerated, commemorated, kubrick, lanka, oslo, cooperates,
# Nearest to other: different, various, both, these, rather, less, bhaktivedanta, modern,
# Nearest to however: but, although, though, while, that, enacting, hydrodynamics, when,
# Nearest to all: many, some, various, own, every, micronation, several, evelyn,
# Nearest to the: their, his, its, a, another, this, each, any,
# Nearest to i: we, ii, g, you, kyrgyz, connectors, they, snare,
# Nearest to states: kingdom, nations, vassar, gap, division, honours, garrett, chanel,
# Nearest to during: in, within, until, after, over, before, since, when,
# Average loss at step 22000: 3.361377
# Average loss at step 24000: 3.291730
# Average loss at step 26000: 3.261789
# Average loss at step 28000: 3.282424
# Average loss at step 30000: 3.230843
# Nearest to were: are, was, is, include, became, stomping, including, be,
# Nearest to there: they, it, davidson, liga, centimetre, himachal, you, pans,
# Nearest to or: and, than, variational, pardoned, but, diagonally, centerpiece, ptc,
# Nearest to many: some, several, various, all, most, these, numerous, few,
# Nearest to are: were, is, include, persist, was, including, redox, have,
# Nearest to was: is, became, were, had, becomes, being, are, has,
# Nearest to four: five, six, seven, eight, three, nine, zero, quake,
# Nearest to six: eight, five, seven, three, four, nine, two, zero,
# Nearest to war: wars, typhoon, approximation, locator, commemorated, nlcs, lintel, absorb,
# Nearest to other: different, various, rather, those, these, many, several, tuatha,
# Nearest to however: although, but, because, though, cacti, until, since, that,
# Nearest to all: many, some, any, various, both, every, several, reparation,
# Nearest to the: a, their, his, its, this, our, clades, pravda,
# Nearest to i: g, ii, daedalus, figurines, mail, you, electrophysiology, castration,
# Nearest to states: kingdom, nations, endorse, honours, husky, smooth, gap, massoud,
# Nearest to during: before, after, since, in, until, within, throughout, when,
# Average loss at step 32000: 3.002693
# Average loss at step 34000: 3.194654
# Average loss at step 36000: 3.198116
# Average loss at step 38000: 3.158551
# Average loss at step 40000: 3.162783
# Nearest to were: are, was, is, include, persist, being, had, became,
# Nearest to there: considered, longer, it, liga, she, infringing, they, cart,
# Nearest to or: and, than, including, while, balaenoptera, amounted, jaroslav, outpouring,
# Nearest to many: some, several, various, all, numerous, both, most, hundreds,
# Nearest to are: were, is, was, include, persist, being, dost, chaldea,
# Nearest to was: is, became, were, are, has, had, remains, becomes,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to six: five, eight, seven, four, three, zero, nine, two,
# Nearest to war: wars, elizabeth, exceeded, typhoon, approximation, cha, lanka, semblance,
# Nearest to other: various, rather, others, including, irritating, those, many, local,
# Nearest to however: but, although, though, that, while, because, where, and,
# Nearest to all: various, many, every, some, several, any, prosecutor, esau,
# Nearest to the: a, its, his, their, any, this, pravda, cricketing,
# Nearest to i: ii, g, hens, chewed, willingly, series, transmigration, counterfeit,
# Nearest to states: kingdom, nations, state, gap, vassar, endorse, assistants, subtext,
# Nearest to during: after, before, in, when, throughout, within, since, until,
# Average loss at step 42000: 3.203445
# Average loss at step 44000: 3.144505
# Average loss at step 46000: 3.142828
# Average loss at step 48000: 3.058756
# Average loss at step 50000: 3.060498
# Nearest to were: are, was, being, is, include, inflate, schedel, have,
# Nearest to there: they, it, davidson, considered, really, revitalized, liga, toss,
# Nearest to or: and, than, like, matchup, sulu, backstory, ouagadougou, pee,
# Nearest to many: several, some, various, numerous, all, few, certain, both,
# Nearest to are: were, is, was, include, includes, amyotrophic, persist, margot,
# Nearest to was: is, were, became, are, had, being, becomes, wrote,
# Nearest to four: five, three, seven, six, eight, nine, zero, two,
# Nearest to six: five, eight, seven, four, three, nine, zero, two,
# Nearest to war: wars, founding, exceeded, semblance, yerba, diagram, outlining, approximation,
# Nearest to other: various, others, rather, different, multiple, smaller, irritating, both,
# Nearest to however: although, while, though, where, that, especially, but, since,
# Nearest to all: many, several, some, various, certain, any, every, these,
# Nearest to the: its, his, a, their, your, an, this, another,
# Nearest to i: ii, g, we, hens, castration, mail, pared, daedalus,
# Nearest to states: kingdom, nations, vassar, assistants, petals, provinces, garrett, gap,
# Nearest to during: throughout, before, in, until, after, when, since, within,
# Average loss at step 52000: 3.099107
# Average loss at step 54000: 3.097748
# Average loss at step 56000: 2.919516
# Average loss at step 58000: 3.020088
# Average loss at step 60000: 3.049996
# Nearest to were: are, was, is, margot, being, persist, be, hickman,
# Nearest to there: they, longer, unconstitutional, davidson, unknown, dystopia, liga, willing,
# Nearest to or: and, than, while, trilemma, intersystems, means, baptised, but,
# Nearest to many: several, some, various, numerous, all, hundreds, most, few,
# Nearest to are: were, is, was, including, have, remain, include, margot,
# Nearest to was: is, became, were, becomes, had, remains, has, are,
# Nearest to four: three, six, five, seven, eight, two, zero, nine,
# Nearest to six: five, seven, eight, four, three, nine, zero, two,
# Nearest to war: wars, founding, lintel, mujahidin, exceeded, diagram, trinity, separators,
# Nearest to other: various, different, these, habitus, political, irritating, several, opposing,
# Nearest to however: although, but, though, while, and, because, especially, when,
# Nearest to all: several, many, some, various, every, certain, both, any,
# Nearest to the: a, its, their, another, an, this, any, his,
# Nearest to i: ii, castration, iv, mail, hotter, we, needlessly, proposals,
# Nearest to states: kingdom, nations, provinces, assistants, vassar, athenians, petals, gap,
# Nearest to during: before, in, throughout, after, until, since, post, within,
# Average loss at step 62000: 3.014700
# Average loss at step 64000: 2.915246
# Average loss at step 66000: 2.941556
# Average loss at step 68000: 2.976013
# Average loss at step 70000: 3.009429
# Nearest to were: are, was, is, been, had, persist, laurence, inflate,
# Nearest to there: they, longer, unconstitutional, davidson, it, willing, considered, indra,
# Nearest to or: and, matchup, than, perceives, overheard, etc, camino, intransitive,
# Nearest to many: several, some, various, all, numerous, multiple, those, these,
# Nearest to are: were, is, was, include, including, have, margot, exist,
# Nearest to was: is, were, are, became, been, becomes, has, had,
# Nearest to four: three, five, six, seven, two, eight, kohen, zero,
# Nearest to six: five, seven, three, eight, four, two, zero, nine,
# Nearest to war: wars, founding, mujahidin, separators, trinity, lintel, exceeded, season,
# Nearest to other: various, multiple, smaller, individual, rather, these, earlier, different,
# Nearest to however: although, but, though, because, while, when, despite, since,
# Nearest to all: many, several, both, some, various, certain, every, numerous,
# Nearest to the: a, his, their, any, its, our, melancholic, clades,
# Nearest to i: g, ii, you, we, needlessly, heavenly, castration, amalthea,
# Nearest to states: kingdom, nations, vassar, gap, state, provinces, assistants, bipeds,
# Nearest to during: in, after, before, throughout, at, when, despite, under,
# Average loss at step 72000: 2.944591
# Average loss at step 74000: 2.863226
# Average loss at step 76000: 3.004426
# Average loss at step 78000: 3.004580
# Average loss at step 80000: 2.844584
# Nearest to were: are, was, is, newly, insurrections, lanthanides, include, hispanics,
# Nearest to there: they, longer, it, these, ligaments, qualified, he, escorial,
# Nearest to or: and, than, inalienable, but, emotional, sclerosis, bandleaders, movers,
# Nearest to many: several, some, various, numerous, all, multiple, both, most,
# Nearest to are: were, is, include, was, contain, have, exist, including,
# Nearest to was: is, were, became, becomes, are, had, has, requires,
# Nearest to four: five, six, three, seven, eight, zero, two, nine,
# Nearest to six: seven, eight, five, three, four, nine, zero, two,
# Nearest to war: wars, founding, mujahidin, conflict, scribner, lintel, washes, history,
# Nearest to other: various, rather, several, multiple, larger, both, these, irritating,
# Nearest to however: although, though, but, while, because, etc, that, where,
# Nearest to all: many, various, every, some, any, several, both, most,
# Nearest to the: its, their, his, a, another, any, our, clades,
# Nearest to i: g, ii, you, castration, mail, they, mallet, we,
# Nearest to states: nations, kingdom, provinces, state, countries, vassar, regions, parts,
# Nearest to during: throughout, before, after, in, until, within, since, at,
# Average loss at step 82000: 2.937097
# Average loss at step 84000: 2.899128
# Average loss at step 86000: 2.921570
# Average loss at step 88000: 2.942878
# Average loss at step 90000: 2.827851
# Nearest to were: are, was, is, newly, include, represent, categorize, had,
# Nearest to there: they, it, she, longer, liga, considered, unconstitutional, these,
# Nearest to or: and, than, balaenoptera, without, xxxv, parabola, contour, overland,
# Nearest to many: some, several, numerous, various, all, both, most, hundreds,
# Nearest to are: were, is, include, was, contain, includes, represent, exist,
# Nearest to was: is, were, became, had, becomes, are, has, exploitable,
# Nearest to four: five, three, six, eight, seven, nine, zero, two,
# Nearest to six: three, seven, four, five, eight, nine, two, zero,
# Nearest to war: wars, cup, founding, scribner, mujahidin, colony, squad, xb,
# Nearest to other: various, larger, multiple, rather, paranormal, more, smaller, different,
# Nearest to however: although, though, but, while, since, ribbon, include, if,
# Nearest to all: various, many, some, several, every, certain, none, both,
# Nearest to the: its, a, any, their, his, our, an, this,
# Nearest to i: g, ii, iv, mallet, we, you, hens, sustaining,
# Nearest to states: nations, kingdom, provinces, bipeds, vassar, countries, adrift, nsc,
# Nearest to during: throughout, in, before, after, until, since, at, within,
# Average loss at step 92000: 2.897516
# Average loss at step 94000: 2.886601
# Average loss at step 96000: 2.715713
# Average loss at step 98000: 2.453664
# Average loss at step 100000: 2.709603
# Nearest to were: are, was, newly, have, include, remain, is, had,
# Nearest to there: they, it, longer, unconstitutional, liga, essentially, considered, depicted,
# Nearest to or: and, than, but, etc, boundless, like, summa, nor,
# Nearest to many: several, some, numerous, various, thousands, both, hundreds, all,
# Nearest to are: were, is, was, include, contain, remain, have, includes,
# Nearest to was: is, became, were, remains, remained, are, makes, had,
# Nearest to four: three, six, five, seven, eight, two, zero, nine,
# Nearest to six: seven, five, four, eight, three, nine, zero, two,
# Nearest to war: wars, colony, cup, revolution, think, il, heritage, conflict,
# Nearest to other: various, different, earlier, these, others, fewer, both, more,
# Nearest to however: although, but, though, while, zyklon, and, when, until,
# Nearest to all: every, various, some, many, several, identical, ten, any,
# Nearest to the: a, its, his, their, her, our, any, your,
# Nearest to i: we, you, ii, g, iv, they, mail, iii,
# Nearest to states: kingdom, nations, state, provinces, bipeds, vassar, villain, airlines,
# Nearest to during: throughout, in, until, after, at, since, despite, around,
